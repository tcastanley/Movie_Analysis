# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# 'C:\\Users\\tcast\\Data Science Program\\Module 1\\Mod 1 Project - Movie Analysis\\dsc-mod-1-project-v2-1-onl01-dtsc-ft-052620'

# %%
df = pd.read_csv('zippedData/bom.movie_gross.csv.gz')

# %%
print(df.shape)
df.head()
# Out:
# (3387, 5)
#                                          title studio  domestic_gross foreign_gross  year
# 0                                  Toy Story 3     BV     415000000.0     652000000  2010
# 1                   Alice in Wonderland (2010)     BV     334200000.0     691300000  2010
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0     664300000  2010
# 3                                    Inception     WB     292600000.0     535700000  2010
# 4                          Shrek Forever After   P/DW     238700000.0     513900000  2010

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
# title             3387 non-null object
# studio            3382 non-null object
# domestic_gross    3359 non-null float64
# foreign_gross     2037 non-null object
# year              3387 non-null int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
df.describe()
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %%
df.isnull().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
df.dropna(subset=['domestic_gross'], inplace=True)
df.dropna(subset=['studio'], inplace=True)
df.isna().sum()
# Out:
# title                0
# studio               0
# domestic_gross       0
# foreign_gross     1349
# year                 0
# dtype: int64

# %%
df.year.unique()
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], dtype=int64)

# %%
df['foreign_gross'] = df['foreign_gross'].str.replace(',','').replace('.','00000')
df['foreign_gross'] = df['foreign_gross'].fillna('1')
df['foreign_gross'] = df['foreign_gross'].astype(int)
df.sort_values('foreign_gross', ascending=False)
# Out:
#                                                   title    studio  domestic_gross  foreign_gross  year
# 3079                             Avengers: Infinity War        BV     678800000.0     1369000005  2018
# 1874                                          Furious 7      Uni.     353000000.0     1163000000  2015
# 1872                       Star Wars: The Force Awakens        BV     936700000.0     1131000006  2015
# 1873                                     Jurassic World      Uni.     652300000.0     1019000004  2015
# 2760                            The Fate of the Furious      Uni.     226000000.0     1010000000  2017
# 328         Harry Potter and the Deathly Hallows Part 2        WB     381000000.0      960500000  2011
# 1875                            Avengers: Age of Ultron        BV     459000000.0      946400000  2015
# 727                               Marvel's The Avengers        BV     623400000.0      895500000  2012
# ...

# %%
df['total_gross'] = df['domestic_gross'] + df['foreign_gross']
df.sort_values('total_gross', ascending=False)
# Out:
#                                                   title      studio  domestic_gross  foreign_gross  year   total_gross
# 1872                       Star Wars: The Force Awakens          BV     936700000.0     1131000006  2015  2.067700e+09
# 3079                             Avengers: Infinity War          BV     678800000.0     1369000005  2018  2.047800e+09
# 1873                                     Jurassic World        Uni.     652300000.0     1019000004  2015  1.671300e+09
# 727                               Marvel's The Avengers          BV     623400000.0      895500000  2012  1.518900e+09
# 1874                                          Furious 7        Uni.     353000000.0     1163000000  2015  1.516000e+09
# 1875                            Avengers: Age of Ultron          BV     459000000.0      946400000  2015  1.405400e+09
# 3080                                      Black Panther          BV     700100000.0      646900000  2018  1.347000e+09
# ...

# %%
print(df['studio'].value_counts())
df.describe()
# Out:
# IFC             166
# Uni.            147
# WB              140
# Fox             136
# Magn.           136
# SPC             123
# Sony            109
# BV              106
# LGF             102
# Par.            101
# Eros             89
# Wein.            77
# CL               73
# Strand           68
# RAtt.            66
# FoxS             66
# KL               62
# Focus            60
# WGUSA            58
# CJ               56
# MBox             54
# A24              49
# UTV              49
# WB (NL)          45
# FM               42
# LG/S             41
# Cohen            40
# ORF              37
# Rela.            35
# SGem             35
# FIP              25
# STX              24
# Gold.            24
# GK               24
# TriS             23
# Osci.            23
# MNE              22
# BST              22
# EOne             21
# Drft.            20
# Distrib.         20
# RTWC             19
# Anch.            18
# CBS              17
# Relbig.          17
# ...

# %%
df.groupby('year').sum().plot.barh(figsize=(15,10), stacked=True);

# %%
for i in df_dict: 
   df_dict[i].to_csv[i]

# %%
# df_country_list


df_counthry = df_country.groupby(['region','primary_title']).sum()
# df_country = df_country.unstack()

# df_country = df_country.sum(axis=0).sort_values(ascending=False)
# df_country = df_country.unstack()

# df_country

# %%
# for movie in df_country.keys():
#     if df_country[movie]['country_count'] <= 1:
#             domestic_films.append(movie)
    
    
# df_country = df_country.drop(domestic_films, axis=1)
# df_country
# .iloc[0].value_counts().plot.barh(figsize=(15,15));
