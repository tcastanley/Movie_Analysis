# %%
import pandas as pd
import matplpotlib.pyplot as plt
import nump as np
import seaborn as sns

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e218fb22073b> in <module>()
#       1 import pandas as pd
# ----> 2 import matplpotlib.pyplot as plt
#       3 import nump as np
#       4 import seaborn as sns
#       5
#
# ModuleNotFoundError: No module named 'matplpotlib'

# %%
df = pd.read_csv('Movie_budgets_and_ratings')
# df[df['movie'] == 'The Texas Chainsaw Massacre']
df[df.duplicated(subset=['movie', 'release_date'], keep=False)]
# Out:
#       Unnamed: 0  release_date                                    movie  \
# 8              8  Nov 17, 2017                           Justice League
# 9              9  Nov 17, 2017                           Justice League
# 10            10   Nov 6, 2015                                  Spectre
# 11            11   Nov 6, 2015                                  Spectre
# 40            40  May 14, 2010                               Robin Hood
# 41            41  May 14, 2010                               Robin Hood
# 42            42  May 14, 2010                               Robin Hood
# 45            45  Feb 16, 2018                            Black Panther
# 46            46  Feb 16, 2018                            Black Panther
# 49            49  Dec 16, 2016             Rogue One: A Star Wars Story
# 50            50  Dec 16, 2016             Rogue One: A Star Wars Story
# 56            56   Mar 5, 2010                      Alice in Wonderland
# ...
